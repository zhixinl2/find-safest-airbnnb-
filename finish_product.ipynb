# %%
import numpy as np
import pandas as pd
import matplotlib as mp
import geopandas as gpd
import descartes
import matplotlib.pyplot as plt

# %%
fp = "Chicago_Community_Areas.shp"
map_df = gpd.read_file(fp)

# %%
map_df.plot()

# %%
map1 = pd.DataFrame(map_df)

# %%
data = pd.read_csv("Crimes_-_Map (1).csv")

# %%
import shapefile as shp
from shapely import geometry
from shapely.geometry import Point 
from shapely.geometry import shape
import csv
from shapely.geometry.polygon import Polygon

# %%
sf = shp.Reader("Chicago_Community_Areas") 
sfRec = sf.records()

n = 0
m = 1
coorDict = {}
matplotDict = []
muniFinal = {}

for shape in sf.shapeRecords(): #Iterate through shapes in shapefile
    x = [i[0] for i in shape.shape.points[:]] #Initially for use in matplotlib to check shapefile
    y = [i[1] for i in shape.shape.points[:]] #Initially for use in matplotlib to check shapefile
    for i in x:
        matplotDict.append((x[x.index(i)],y[x.index(i)])) #Convert coordinates to be read by Shapely pkg

    munishp = Polygon(matplotDict)
    muniFinal[sfRec[n][0]] = munishp #Store shape in dictionary with key of municipality
    
    matplotDict = [] #refresh coordinate store for next shape   
    n += 1 
n = 0

# %%
lat = data['LATITUDE']
pd.Series(lat).astype(float)
lon = data['LONGITUDE']
pd.Series(lon).astype(float)
coor = list(zip(lon,lat))
coordict = {}
for i in  range(len(coor)):
  coorDict[i]=coor[i]

# %%
result = []
for j in coorDict:
    for k in muniFinal:
        if Point(coorDict[j]).within(muniFinal[k]):
            result.append(k-1)

# %%
fre=[]
def CountFrequency(my_list): 
  
    # Creating an empty dictionary  
    freq = {} 
    for item in my_list: 
        if (item in freq): 
            freq[item] += 1
        else: 
            freq[item] = 1

    for key, value in freq.items(): 
         fre.append((key, value))
    
if __name__ == "__main__":  
    my_list = result
    CountFrequency(my_list)

freDict = dict(fre)
freq = [(k,freDict[k]) for k in sorted(freDict.keys())] 
datafre = pd.DataFrame(freq)
datafre = datafre.rename(columns = {1:'crime'})
datafre = datafre.set_index(0)

# %%
map2 = map1.join(datafre)
map2['crime'].fillna(0,inplace=True)
a = map2['COMMUNITY']
b = map2['crime']
map3 = pd.DataFrame([a,b])
map3 = map3.T

# %%
merged = map_df.set_index('COMMUNITY').join(map3.set_index('COMMUNITY'))
merged.sort_values('crime',inplace=True,ascending=True)

# %%
variable = 'crime'
vmin, vmax = 500, 5000
fig, ax = plt.subplots(1, figsize=(10, 10))
merged.plot(column=variable, cmap='Blues', linewidth=0.8, ax=ax, edgecolor='0.8')
ax.axis('off')
ax.set_title('Crime in Chicago Communities', fontdict={'fontsize': '25', 'fontweight' : '3'})
sm = plt.cm.ScalarMappable(cmap='Blues', norm=plt.Normalize(vmin=vmin, vmax=vmax))
sm._A = []
cbar = fig.colorbar(sm)

# %%
canDict = dict((k,muniFinal[k])for k in (35,38,39))
canDict
# Out:
# {35: <shapely.geometry.polygon.Polygon at 0x11c94a9b0>,
#  38: <shapely.geometry.polygon.Polygon at 0x11c94aa58>,
#  39: <shapely.geometry.polygon.Polygon at 0x11c94aa90>}

# %%
# store every location within three 
# chosen neighbhoods
can = []
for j in coorDict:
    for k in canDict:
        if Point(coorDict[j]).within(canDict[k]):
            can.append((coorDict[j]))

# %%
# slice 'near south side' crime locations
can_a=[]
for q in range(0,len(can)):
    if Point(can[q]).within(canDict[35]):
        can_a.append(can[q])

# %%
# slice 'armour square' crime locations
can_b=[]
for x in range(0,len(can)):
    if Point(can[x]).within(canDict[38]):
        can_b.append(can[x])

# %%
# slice 'bridgeport' crime locations
can_c=[]
for y in range(0,len(can)):
    if Point(can[y]).within(canDict[39]):
        can_c.append(can[y])

# %%
crime_count=len(can_c)+len(can_b)+len(can_a)+1

# %%
# how many elements in three neighbourhood?
print("Crime Couunts for filtered neighborhoods:"+ "%s" %crime_count)
# Out:
# Crime Couunts for filtered neighborhoods:4334

# %% [markdown]
# From the map,the neighbourhood we selected are **Near South Side**, **Armour Sqaure** and **Bridgeport**.

# %%
neigh_selec=['Near South Side','Bridgeport','Armour Sqaure']

# %%
airbnb_df= pd.read_csv("listings.csv")

# %%
#### get three community airbnb listing separated 

# near south side 
airbnb_df_35=airbnb_df.loc[(airbnb_df['neighbourhood_cleansed']=='Near South Side')].reset_index()

# ARMOUR SQUARE
airbnb_df_38=airbnb_df.loc[(airbnb_df['neighbourhood_cleansed']=='Armour Square')].reset_index()

# bridgeport               
airbnb_df_39=airbnb_df.loc[(airbnb_df['neighbourhood_cleansed']=='Bridgeport')].reset_index()

# %%
## code chuck for calculating distance 
from math import radians, cos, sin, asin, sqrt
def haversine(lon1, lat1, lon2, lat2):
    """
    Calculate the great circle distance between two points 
    on the earth (specified in decimal degrees)
    """
    # convert decimal degrees to radians 
    lon1, lat1, lon2, lat2 = map(radians, [lon1, lat1, lon2, lat2])
    # haversine formula 
    dlon = lon2 - lon1 
    dlat = lat2 - lat1 
    a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2
    c = 2 * asin(sqrt(a)) 
    # Radius of earth in kilometers is 6371
    km = 6371* c
    return km

# %%
can_a=np.array(can_a)

# %%
# create a dataframe to store all the distance for community 33
distance_a=pd.DataFrame(data=np.zeros((can_a.shape[0],airbnb_df_35.shape[0])))

# %%
# checking crime counts for near south 
# side for every listing within 0.1km
import gc
for i in list(distance_a.columns):
    # loop over every listing
    lat1 = list(airbnb_df_35.loc[i,['latitude','longitude']].values)[0]
    lon1 = list(airbnb_df_35.loc[i,['latitude','longitude']].values)[1]
    
    for j in range(0,can_a.shape[0]):
        # loop over every crime 
        lat2 = can_a[j,][1]
        lon2 = can_a[j,][0]
        # print(j)
        distance_a.loc[j,i]=haversine(lon1,lat1,lon2,lat2)
        gc.enable()
        if j % 100== 0:
            # print("%s"%j+" times done!")
            gc.collect()
    if i%10 ==0:
        print("%s"%i+" listing done!")
# Out:
# 0 listing done!
# 10 listing done!
# 20 listing done!
# 30 listing done!
# 40 listing done!
# 50 listing done!
# 60 listing done!
# 70 listing done!
# 80 listing done!
# 90 listing done!
# 100 listing done!
# 110 listing done!
# 120 listing done!
# 130 listing done!
# 140 listing done!

# %%
count_list=[]
for listing in list(distance_a.columns):
    count=np.sum(distance_a.loc[:,listing].values<=0.1)
    count_list.append(count)

# %%
len(count_list)
# Out:
# array([1.2584249 , 0.52925933, 1.79570199, ..., 0.05856304, 0.85035054,
#        1.44388135])

# %%
airbnb_df_35['crime_within_pt1']=count_list

# %%
final_for_nearlakeside=airbnb_df_35.sort_values(by='crime_within_pt1',ascending=True)

# %%
final_for_nearlakeside.to_csv("final_for_nearlakeside.csv")

# %% [markdown]
# ----

# %%
can_b=np.array(can_b)

# %%
# create a dataframe to store all the distance for community 38
distance_b=pd.DataFrame(data=np.zeros((can_b.shape[0],airbnb_df_38.shape[0])))

# %%
# checking crime counts for near armour
# square for every listing within 0.1km

for i in list(distance_b.columns):
    # loop over every listing
    lat1 = list(airbnb_df_38.loc[i,['latitude','longitude']].values)[0]
    lon1 = list(airbnb_df_38.loc[i,['latitude','longitude']].values)[1]
    
    for j in range(0,can_b.shape[0]):
        # loop over every crime 
        lat2 = can_b[j,][1]
        lon2 = can_b[j,][0]
        # print(j)
        distance_b.loc[j,i]=haversine(lon1,lat1,lon2,lat2)
        gc.enable()
        if j % 100== 0:
            # print("%s"%j+" times done!")
            gc.collect()
    if i%10 ==0:
        print("%s"%i+" listing done!")
# Out:
# 0 listing done!
# 10 listing done!
# 20 listing done!
# 30 listing done!
# 40 listing done!
# 50 listing done!
# 60 listing done!
# 70 listing done!
# 80 listing done!

# %%
count_list=[]
for listing in list(distance_b.columns):
    count=np.sum(distance_b.loc[:,listing].values<=0.1)
    count_list.append(count)

# %%
airbnb_df_38['crime_within_pt1']=count_list

# %%
final_for_armoursquare=airbnb_df_38.sort_values(by='crime_within_pt1',ascending=True)

# %%
final_for_armoursquare
# Out:
#     index        id                            listing_url       scrape_id  \
# 3     502   4503332   https://www.airbnb.com/rooms/4503332  20181115100644
# 58   5137  24541340  https://www.airbnb.com/rooms/24541340  20181115100644
# 37   3461  20177013  https://www.airbnb.com/rooms/20177013  20181115100644
# 43   3886  21204267  https://www.airbnb.com/rooms/21204267  20181115100644
# 22   2811  18073252  https://www.airbnb.com/rooms/18073252  20181115100644
# 17   2315  15597127  https://www.airbnb.com/rooms/15597127  20181115100644
# 11   1445  11661652  https://www.airbnb.com/rooms/11661652  20181115100644
# 47   3975  21380109  https://www.airbnb.com/rooms/21380109  20181115100644
# 0     373   3430491   https://www.airbnb.com/rooms/3430491  20181115100644
# 6     942   7783924   https://www.airbnb.com/rooms/7783924  20181115100644
# 62   5341  25027784  https://www.airbnb.com/rooms/25027784  20181115100644
# 69   6467  27775938  https://www.airbnb.com/rooms/27775938  20181115100644
# 19   2554  16620615  https://www.airbnb.com/rooms/16620615  20181115100644
# 7    1113   8747106   https://www.airbnb.com/rooms/8747106  20181115100644
# 50   4741  23455723  https://www.airbnb.com/rooms/23455723  20181115100644
# 4     503   4503414   https://www.airbnb.com/rooms/4503414  20181115100644
# 63   5394  25143047  https://www.airbnb.com/rooms/25143047  20181115100644
# 35   3218  19469209  https://www.airbnb.com/rooms/19469209  20181115100644
# 45   3953  21327601  https://www.airbnb.com/rooms/21327601  20181115100644
# 13   1563  12334385  https://www.airbnb.com/rooms/12334385  20181115100644
# 14   1631  12874125  https://www.airbnb.com/rooms/12874125  20181115100644
# 12   1518  12159371  https://www.airbnb.com/rooms/12159371  20181115100644
# 77   7164  29277046  https://www.airbnb.com/rooms/29277046  20181115100644
# 21   2807  18047767  https://www.airbnb.com/rooms/18047767  20181115100644
# 8    1282  10119226  https://www.airbnb.com/rooms/10119226  20181115100644
# 38   3518  20321044  https://www.airbnb.com/rooms/20321044  20181115100644
# 54  Beautiful and newly renovated 2 bedroom 1 bath...
# 67  My place is by Chinatown square. Easy access d...
# 52                                                  1
# 29  My place is by Chinatown square. Easy access d...
# 81  This is the Best location,half a block away fr...
# 23  My place is by Chinatown square. Easy access d...
# 36  Apartment is in the 6 unit Building.Total remo...
#
#                                                 space  \
# 3   This is a 3 bed/1.5 bath fully furnished unit ...
# 58                                    一间卧室可以住俩人一个双人床｡
# 37  - New bed and towels for every guest! - Walkin...
# 43  My space is a newly renovated duplex.  It is c...
# 22                                                NaN
# 17  唐人街中心位置,交通､饮食方便,有地铁､巴士到市中心､机场,近默康尔中心唐人街中心区,周边各...
# 11                                                NaN
# 47                                                NaN
# 0   Vintage loft building, unique corner unit with...
# 6   You get a private bedroom with a closet, hange...
# 62  独立单间,房内一张上下床,可以住2⃣️人,旁边有另一独立单间,旁边有独立茶水间,有一独立公共...
# 69                       Suitable for business travel
# 19  Newly Renovated Brand new bathrooms with heate...
# 7   Guests can use the whole unit - except the sto...
# 50  You get a private bedroom with a closet, hange...
# 4   This is a private bedroom with shared bathroom...
# 63  The sun lights up this beauty during the day. ...
# 35                                                NaN
# 45                                                NaN
# 13  Cozy vintage style apartment located in Chinat...
# 14  Cozy vintage style apartment located in Chinat...
# 12  Cozy vintage style apartment located in Chinat...
# 77  A new furnished apartment, suitable for 11 peo...
# 21                                                NaN
# 8                                                 NaN
# 38  Apart of your room and your own bathroom, you ...
# 64                                                NaN
# 10  Cozy vintage style apartment located in Chinat...
# 70                       Suitable for business travel
# 1   The space has 2.5 bedrooms and 1.5 bath. One o...
# ..                                                ...
# 30                                                NaN
# 78  Space Our condo apartment is conveniently situ...
# 59  中国城中心就算半夜里也有吃的提供价格也便宜,出门几乎不用坐车想到城市中心与公园都方便!如果你...
# 46                                                NaN
# 73                                                NaN
# 61  My apartment has an elevator. The room is quie...
# 80  This is a modern and minimalist place and You ...
# 26                                                NaN
# 5   This space is perfect for 1 person wanting pri...
# 72  This deluxe suite is a combination suite. Depe...
# 68  This deluxe suite is a combination of 2 separa...
# 25                                                NaN
# 42                                                NaN
# 71  Our home is uniquely situated in a quiet and c...
# 79  This is a modern and minimalist place and You ...
# 56                                                NaN
# 39                                                NaN
# 65                                                NaN
# 24                                                NaN
# 28                                                NaN
# 66  Bedroom 1 has two (2) Double Beds. Bedroom 2 h...
# 34                                                NaN
# 55                                                NaN
# 54                                                NaN
# 67                                                NaN
# 52                                                NaN
# 29                                                NaN
# 81  This is a modern and minimalist place and You ...
# 23                                                NaN
# 36  My place is in the heart of Chinatown resident...
#
#                                           description experiences_offered  \
# 3   This is a fully furnished unit located on the ...                none
# 58  我的房子临街有一个小门进入,房子是黄色联排别墅房,但我有自己的独立进入出口与别家不同!园子里...                none
# 37  Welcome to Chicago!  Michael and I felt in lov...                none
# 43  Duplex located in Bridgeport, Chicago.  Great ...                none
# 22  This private apartment has 3 bedrooms that can...                none
# 17  Private bedroom with multiple bathrooms in a v...                none
# 36  Apartment is in the 6 unit Building.Total remo...                none
#
#     ...                    license  \
# 3   ...               R18000034071
# 58  ...               R18000034077
# 37  ...  City registration pending
# 43  ...  City registration pending
# 22  ...               C17000008460
# 17  ...  City registration pending
# 11  ...  City registration pending
# 47  ...  City registration pending
# 0   ...  City registration pending
# 6   ...               R17000015541
# 62  ...  City registration pending
# 69  ...  City registration pending
# 19  ...  City registration pending
# 7   ...  City registration pending
# 50  ...               R17000015541
# 4   ...  City registration pending
# 63  ...               R18000026850
# 35  ...  City registration pending
# 45  ...  City registration pending
# 13  ...  City registration pending
# 14  ...  City registration pending
# 12  ...  City registration pending
# 77  ...  City registration pending
# 21  ...  City registration pending
# 8   ...               R17000014302
# 38  ...               R17000020475
# 64  ...                 3125325470
# 10  ...  City registration pending
# 70  ...  City registration pending
# 1   ...               R18000033638
# ..  ...                        ...
# 30  ...  City registration pending
# 78  ...  City registration pending
# 59  ...  City registration pending
# 46  ...               R18000034950
# 73  ...  City registration pending
# 61  ...  City registration pending
# 80  ...  City registration pending
# 26  ...  City registration pending
# 5   ...               R17000014027
# 72  ...  City registration pending
# 68  ...  City registration pending
# 25  ...  City registration pending
# 42  ...  City registration pending
# 71  ...               R18000031701
# 79  ...  City registration pending
# 56  ...  City registration pending
# 39  ...  City registration pending
# 65  ...               R17000015578
# 24  ...  City registration pending
# 28  ...  City registration pending
# 66  ...  City registration pending
# 34  ...               R17000013556
# 55  ...               R18000031979
# 54  ...  City registration pending
# 67  ...               R17000015578
# 52  ...               R17000015578
# 29  ...  City registration pending
# 81  ...  City registration pending
# 23  ...  City registration pending
# 36  ...  City registration pending
#
#                                    jurisdiction_names instant_bookable  \
# 3   {"Illinois State"," Cook County"," IL"," CHICA...                f
# 58  {"Illinois State"," Cook County"," IL"," CHICA...                f
# 37  {"Illinois State"," Cook County"," IL"," CHICA...                t
# 43  {"Illinois State"," Cook County"," IL"," CHICA...                t
# 22  {"Illinois State"," Cook County"," IL"," CHICA...                t
# 17  {"Illinois State"," Cook County"," IL"," CHICA...                t
# 11  {"Illinois State"," Cook County"," IL"," CHICA...                f
# 47  {"Illinois State"," Cook County"," IL"," CHICA...                t
# 0   {"Illinois State"," Cook County"," IL"," CHICA...                f
# 6   {"Illinois State"," Cook County"," IL"," CHICA...                t
# 62  {"Illinois State"," Cook County"," IL"," CHICA...                t
# 69  {"Illinois State"," Cook County"," IL"," CHICA...                t
# 19  {"Illinois State"," Cook County"," IL"," CHICA...                t
# 7   {"Illinois State"," Cook County"," IL"," CHICA...                f
# 50  {"Illinois State"," Cook County"," IL"," CHICA...                t
# 4   {"Illinois State"," Cook County"," IL"," CHICA...                f
# 63  {"Illinois State"," Cook County"," IL"," CHICA...                t
# 35  {"Illinois State"," Cook County"," IL"," CHICA...                t
# 45  {"Illinois State"," Cook County"," IL"," CHICA...                t
# 13  {"Illinois State"," Cook County"," IL"," CHICA...                t
# 14  {"Illinois State"," Cook County"," IL"," CHICA...                t
# 12  {"Illinois State"," Cook County"," IL"," CHICA...                t
# 77  {"Illinois State"," Cook County"," IL"," CHICA...                t
# 21  {"Illinois State"," Cook County"," IL"," CHICA...                f
# 8   {"Illinois State"," Cook County"," IL"," CHICA...                f
# 38  {"Illinois State"," Cook County"," IL"," CHICA...                t
# 64  {"Illinois State"," Cook County"," IL"," CHICA...                t
# 10  {"Illinois State"," Cook County"," IL"," CHICA...                t
# 70  {"Illinois State"," Cook County"," IL"," CHICA...                t
# 1   {"Illinois State"," Cook County"," IL"," CHICA...                f
# ..                                                ...              ...
# 30  {"Illinois State"," Cook County"," IL"," CHICA...                t
# 78  {"Illinois State"," Cook County"," IL"," CHICA...                t
# 59  {"Illinois State"," Cook County"," IL"," CHICA...                f
# 46  {"Illinois State"," Cook County"," IL"," CHICA...                t
# 73  {"Illinois State"," Cook County"," IL"," CHICA...                t
# 61  {"Illinois State"," Cook County"," IL"," CHICA...                t
# 80  {"Illinois State"," Cook County"," IL"," CHICA...                t
# 26  {"Illinois State"," Cook County"," IL"," CHICA...                t
# 5   {"Illinois State"," Cook County"," IL"," CHICA...                t
# 72  {"Illinois State"," Cook County"," IL"," CHICA...                f
# 68  {"Illinois State"," Cook County"," IL"," CHICA...                f
# 25  {"Illinois State"," Cook County"," IL"," CHICA...                t
# 42  {"Illinois State"," Cook County"," IL"," CHICA...                t
# 71  {"Illinois State"," Cook County"," IL"," CHICA...                f
# 79  {"Illinois State"," Cook County"," IL"," CHICA...                t
# 56  {"Illinois State"," Cook County"," IL"," CHICA...                t
# 39  {"Illinois State"," Cook County"," IL"," CHICA...                t
# 65  {"Illinois State"," Cook County"," IL"," CHICA...                t
# 24  {"Illinois State"," Cook County"," IL"," CHICA...                t
# 28  {"Illinois State"," Cook County"," IL"," CHICA...                t
# 66  {"Illinois State"," Cook County"," IL"," CHICA...                t
# 34  {"Illinois State"," Cook County"," IL"," CHICA...                t
# 55  {"Illinois State"," Cook County"," IL"," CHICA...                t
# 54  {"Illinois State"," Cook County"," IL"," CHICA...                t
# 67  {"Illinois State"," Cook County"," IL"," CHICA...                t
# 52  {"Illinois State"," Cook County"," IL"," CHICA...                f
# 29  {"Illinois State"," Cook County"," IL"," CHICA...                t
# 81  {"Illinois State"," Cook County"," IL"," CHICA...                t
# 23  {"Illinois State"," Cook County"," IL"," CHICA...                t
# 36  {"Illinois State"," Cook County"," IL"," CHICA...                t
#
#    is_business_travel_ready          cancellation_policy  \
# 3                         f                     flexible
# 58                        f                     moderate
# 37                        f  strict_14_with_grace_period
# 43                        f  strict_14_with_grace_period
# 22                        f                     moderate
# 17                        f                     moderate
# 11                        f  strict_14_with_grace_period
# 47                        f  strict_14_with_grace_period
# 0                         f                     moderate
# 6                         f                     moderate
# 62                        f                     moderate
# 69                        f                     moderate
# 19                        f                     moderate
# 7                         f                     moderate
# 50                        f  strict_14_with_grace_period
# 4                         f                     flexible
# 63                        f  strict_14_with_grace_period
# 35                        f  strict_14_with_grace_period
# 45                        f                     moderate
# 13                        f                     moderate
# 14                        f                     moderate
# 12                        f                     flexible
# 77                        f  strict_14_with_grace_period
# 21                        f                     moderate
# 8                         f  strict_14_with_grace_period
# 38                        f                     moderate
# 64                        f                     moderate
# 10                        f                     moderate
# 70                        f                     moderate
# 1                         f                     flexible
# ..                      ...                          ...
# 30                        f                     moderate
# 78                        f  strict_14_with_grace_period
# 59                        f                     flexible
# 46                        f                     moderate
# 73                        f  strict_14_with_grace_period
# 61                        f                     moderate
# 80                        f  strict_14_with_grace_period
# 26                        f                     moderate
# 5                         f                     moderate
# 72                        f  strict_14_with_grace_period
# 68                        f  strict_14_with_grace_period
# 25                        f                     moderate
# 42                        f                     moderate
# 71                        f  strict_14_with_grace_period
# 79                        f  strict_14_with_grace_period
# 56                        f  strict_14_with_grace_period
# 39                        f                     moderate
# 65                        f                     flexible
# 24                        f                     moderate
# 28                        f                     moderate
# 66                        f  strict_14_with_grace_period
# 34                        f  strict_14_with_grace_period
# 55                        f  strict_14_with_grace_period
# 54                        f  strict_14_with_grace_period
# 67                        f                     moderate
# 52                        f                     flexible
# 29                        f                     moderate
# 81                        f  strict_14_with_grace_period
# 23                        f                     moderate
# 36                        f  strict_14_with_grace_period
#
#    require_guest_profile_picture  require_guest_phone_verification  \
# 3                              f                                 f
# 58                             f                                 f
# 37                             f                                 f
# 43                             f                                 f
# 22                             f                                 f
# 17                             f                                 f
# 11                             f                                 f
# 47                             f                                 f
# 0                              f                                 f
# 6                              f                                 f
# 62                             f                                 f
# 69                             f                                 f
# 19                             f                                 f
# 7                              f                                 f
# 50                             f                                 f
# 4                              f                                 f
# 63                             f                                 f
# 35                             f                                 f
# 45                             f                                 f
# 13                             f                                 f
# 14                             f                                 f
# 12                             f                                 f
# 77                             f                                 f
# 21                             f                                 f
# 8                              f                                 f
# 38                             f                                 f
# 64                             f                                 f
# 10                             f                                 f
# 70                             f                                 f
# 1                              f                                 f
# ..                           ...                               ...
# 30                             f                                 f
# 78                             f                                 f
# 59                             f                                 f
# 46                             f                                 f
# 73                             f                                 f
# 61                             f                                 f
# 80                             f                                 f
# 26                             f                                 f
# 5                              f                                 f
# 72                             f                                 f
# 68                             f                                 f
# 25                             f                                 f
# 42                             f                                 f
# 71                             f                                 f
# 79                             f                                 f
# 56                             f                                 f
# 39                             f                                 f
# 65                             f                                 f
# 24                             f                                 f
# 28                             f                                 f
# 66                             f                                 f
# 34                             f                                 f
# 55                             f                                 f
# 54                             f                                 f
# 67                             f                                 f
# 52                             f                                 f
# 29                             f                                 f
# 81                             f                                 f
# 23                             f                                 f
# 36                             f                                 f
#
#     calculated_host_listings_count reviews_per_month  crime_within_pt1
# 3                                4              1.52                 0
# 58                               2              2.86                 0
# 37                              12              3.79                 1
# 43                               1              6.81                 1
# 22                               3              1.46                 1
# 17                              10              3.56                 1
# 11                               6              3.48                 1
# 47                               6              1.88                 2
# 0                                1              4.24                 2
# 6                                2              4.20                 2
# 62                              10              6.55                 3
# 69                               2              3.00                 3
# 19                               1              1.84                 4
# 7                                3              1.50                 4
# 50                               2              1.87                 5
# 4                                4              1.46                 5
# 63                               2              3.04                 5
# 35                               6              3.17                 5
# 45                               9              7.36                 5
# 13                              10              3.71                 5
# 14                              10              4.63                 6
# 12                              10              3.35                 6
# 77                               6              2.00                 7
# 21                               1              3.34                 7
# 8                                1              2.28                 7
# 38                               1              3.73                 7
# 64                               2             10.40                 7
# 10                              10              2.76                 7
# 70                               2              1.61                 7
# 1                                4              1.53                 8
# ..                             ...               ...               ...
# 30                              17              2.15                14
# 78                               2               NaN                15
# 59                               2              3.42                16
# 46                               9              9.15                16
# 73                               3              3.83                18
# 61                               2              8.11                18
# 80                              12               NaN                19
# 26                              17              1.68                19
# 5                                3              3.64                20
# 72                               6              3.05                23
# 68                               6              4.16                26
# 25                              17              1.93                26
# 42                              17              0.81                28
# 71                               5              5.33                29
# 79                              12               NaN                36
# 56                               6              3.27                38
# 39                              17              1.34                40
# 65                              17              2.28                42
# 24                              17              1.19                43
# 28                              17              1.65                43
# 66                               6              3.45                47
# 34                               6              3.35                50
# 55                               6              4.18                60
# 54                               6              4.86                60
# 67                              17              2.76                64
# 52                              17              0.12                65
# 29                              17              1.78                72
# 81                              12               NaN                73
# 23                              17              1.42                78
# 36                               6              2.66                80
#
# [82 rows x 98 columns]

# %%
final_for_armoursquare.to_csv("final_for_armoursquare.csv")

# %% [markdown]
# ----

# %%
can_c =np.array(can_c)

# %%
# create a dataframe to store all the distance for community 39
distance_c=pd.DataFrame(data=np.zeros((can_c.shape[0],airbnb_df_39.shape[0])))

# %%
# checking crime counts for near bridgeport
# for every listing within 0.1km

for i in list(distance_c.columns):
    # loop over every listing
    lat1 = list(airbnb_df_39.loc[i,['latitude','longitude']].values)[0]
    lon1 = list(airbnb_df_39.loc[i,['latitude','longitude']].values)[1]
    
    for j in range(0,can_c.shape[0]):
        # loop over every crime 
        lat2 = can_c[j,][1]
        lon2 = can_c[j,][0]
        # print(j)
        distance_c.loc[j,i]=haversine(lon1,lat1,lon2,lat2)
        gc.enable()
        if j % 100== 0:
            # print("%s"%j+" times done!")
            gc.collect()
    if i%10 ==0:
        print("%s"%i+" listing done!")
# Out:
# 0 listing done!
# 10 listing done!
# 20 listing done!
# 30 listing done!
# 40 listing done!
# 50 listing done!
# 60 listing done!
# 70 listing done!
# 80 listing done!
# 90 listing done!
# 100 listing done!

# %%
count_list=[]
for listing in list(distance_c.columns):
    count=np.sum(distance_c.loc[:,listing].values<=0.1)
    count_list.append(count)

# %%
airbnb_df_39['crime_within_pt1']=count_list

# %%
final_for_bridgeport=airbnb_df_39.sort_values(by='crime_within_pt1',ascending=True)

# %%
final_for_bridgeport

# %%
final_for_bridgeport.to_csv("final_for_bridgeport.csv")
